# %% [markdown]
# # Preliminary Analysis of CNN approach to CRC histology
#
# These notes are based on the paper:
#
# *Predicting survival from colorectal cancer histology slides using deep learning: A retrospective multicenter study*
#
# by Jakob Kather
#
# This is a second iteration applying ML/DL to multi-class classification of CRC tissue sample, and a more-correlated-to-risk-ratio-than-the-gold-standard "deep stroma score"
#
# They achieved a ~95% accuracy on a 9-class classification of the tissue types of small patches of CRC tissue slides. They utilized a transfer from a over-the-counter CNN trained on ImageNet (VGG19).
#
# See slide deck for better

# %% [markdown]
# ## Motivation/Context/Background
#
# "Precision oncology depends on stratification of cancer patients into different groups with different tumor genotypes, phenotypes, and clinical outcome."
#
# "few if any digital pathology biomarkers have made their way into the clinic so far"
#
# Two barriers:
#
# - lack of annotated publically available data.
# - lack of validation to clinically relevant situations with real world data from different institutions.
#
# ## Goal:
#
# 1. Make more data publically available
# 1. "Train a CNN for multiclass tissue classification in CRC histology"
# 1. "build a predictive score from the output neuron activations"
# 1. Validate model with independent data
#
# "we present a novel biomarker that can be incorporated into existing clinical workflows because it only relies on HE images, which are widely available."
#
# "identify high-risk patients with advanced cancer who might benefit from more intense treatment?
#
# "augment and accelerate, the pathologist’s evaluation of tissue slides, at the same time making it more objective and reproducible."
#
#
# "scanning and analyzing them is not very costly"
#
# "our approach is reproducible"
#
#
# "our method and our data sets can be used as a benchmark for future trials."
#
# "having a softmax layer as output, the CNN can also quantify mixtures of different tissues."

# %% [markdown]
# ## Data
#
# * Slides from 4 (retrospective) patient cohorts at different institutions.
#     * $224 \times 224$px with .5 $\mu$m/px (normalized using "Macenko method")

# %% [markdown]
# ## Flowchart of study
#
# ![flow_chart_of_study.png](attachment:bfb471bb-ba06-4076-89b8-ef0c47bb4bc5.png)

# %% [markdown]
# ## Validation
#
# * ~95% accuracy
# * some reasonable deep dream/t-SNE visualizations
# * "this study needs to be validated prospectively before routine clinical us"

# %% [markdown]
# ## What I like about the two studies
#
# 1. Emphasis on the need for prospective follow up studies
# 1. Use of independent data sets for validation/
# 1. Model seems to have performed excellently, with a responsible benchmarks

# %% [markdown]
# ## Random Thoughts
#
# 1. No clear indication of "best practices" for this type of modeling. Many choices seemed opaque and/or ad hoc, with very little theoretical justification.
# 1. Dangers of using of transfer learning?
#     1. Immunoflouresence
# 1. How does one deploy AGILE in a healthcare context?
# 1. What knowledge is being gained by these approaches? What hypotheses are being tested?
